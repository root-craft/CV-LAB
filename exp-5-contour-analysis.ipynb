# %%
# !wget -O exp-5-original.jpg "https://i.postimg.cc/6QTQYNNv/exp-5-original.png"
# Out:
# --2026-02-05 08:55:49--  https://i.postimg.cc/6QTQYNNv/exp-5-original.png
# Resolving i.postimg.cc (i.postimg.cc)... 46.105.222.81, 46.105.222.82, 46.105.222.161, ...
# Connecting to i.postimg.cc (i.postimg.cc)|46.105.222.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 230724 (225K) [image/png]
# Saving to: ‘exp-5-original.jpg’
#
# exp-5-original.jpg  100%[===================>] 225.32K   245KB/s    in 0.9s
#
# 2026-02-05 08:55:52 (245 KB/s) - ‘exp-5-original.jpg’ saved [230724/230724]

# %%
import cv2
import numpy as np

# %%
from google.colab.patches import cv2_imshow as imshow

# %%
# Read image
img = cv2.imread('exp-5-original.jpg')

# %%
# Preprocessing
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
# Edge detection
edges = cv2.Canny(blur, 100, 200)

# %%
# Find contours
contours, _ = cv2.findContours(
    edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
)

# %%
# Draw contours
result = img.copy()
blank = np.zeros(img.shape, dtype=np.uint8)

cv2.drawContours(result, contours, -1, (0, 255, 0), 2)
cv2.drawContours(blank, contours, -1, (255, 255, 255), 2)

# %%
# Display original and processed images
imshow(img)
imshow(result)
imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=508x730>
# <PIL.Image.Image image mode=RGB size=508x730>
# <PIL.Image.Image image mode=RGB size=508x730>
